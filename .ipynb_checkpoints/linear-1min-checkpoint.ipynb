# %%
# Verify that we are using the correct Python (/home/ata/miniconda3/envs/ml/bin/)
# !which python
# !which jupyter
# Out:
# /home/ata/miniconda3/envs/ml-2/bin/python
# /home/ata/miniconda3/envs/ml-2/bin/jupyter

# %%
# Import the class from the Python file (module)
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
from BinanceClient import BinanceClient
import numpy as np
from typing import Final
import joblib
from BatchFeatures import BatchFeatures
from datetime import datetime, timedelta
# %matplotlib widget

# %% [markdown]
# #### Fetch pair data

# %%
# Initialize Binance client with your API credentials
# dotenv_path = Path('.env-secret')
# load_dotenv(dotenv_path=dotenv_path)
api_secret = os.getenv("BINANCE_SECRET_KEY")
api_key = os.getenv("BINANCE_API_KEY")

# Create Binance client & initialize it
pair = "BTCUSDT"
time_delta = 12
db_name = pair + "_1min_" + str(time_delta) + "weeks.db"
db_name = "BTCUSDT_1min_dry_run.db"             # For dry run testing
binance_client = BinanceClient(db_name)
binance_client.set_interval("1m")
batch_feature = BatchFeatures()

# %% [markdown]
# #### Fecth Data from Binance

# %%
# Create connection to fetch data
binance_client.make(api_key, api_secret)

# Get current server time
server_time = binance_client.get_server_time()

# Compute start and end time for the last x hours
server_time_dt = datetime.fromtimestamp(server_time['serverTime'] / 1000, tz=datetime.timezone.utc if hasattr(datetime, 'timezone') else None)
end_date = server_time_dt
# start_date = server_time_dt - timedelta(hours=10)
start_date = server_time_dt - timedelta(weeks=time_delta)
start_date_str = int(start_date.timestamp() * 1000)  # Convert to milliseconds
end_date_str = int(end_date.timestamp() * 1000)      # Convert to milliseconds

# Fetch data
data = binance_client.fetch_data(pair, start_date_str, end_date_str)
binance_client.store_data_to_db(pair, data)

# Check if data is fetched
if not data.empty:
    df = data
else:
    print("No data found!!!.")
# Out:
# Fetching data from Binance API...

# %% [markdown]
# #### Fetch data from db

# %%
#Fetch data from db
df = binance_client.fetch_data_from_db(pair)

# %% [markdown]
# #### Test/Train Splot

# %% [markdown]
# #### Define target

# %% [markdown]
# #### Feature engineering

# %%
# Feature Engineering (mind the order since some features are depended on others)
bf = BatchFeatures()
bf.calculate_sma(df)
bf.calculate_ema(df)
bf.calculate_rsi(df)
bf.calculate_macd(df)
bf.calculate_bollinger_bands(df)
bf.calculate_atr(df)
bf.calculate_volume_features(df)
bf.calculate_roc(df)
bf.calculate_lagged_features(df)
bf.calculate_candle_features(df)
bf.calculate_stochastic_oscillator(df)
bf.calculate_williams_r(df)
bf.calculate_moving_average_crossover(df)
bf.calculate_historical_volatility(df)
bf.calculate_on_balance_volume(df)
bf.calculate_money_flow_index(df)
bf.calculate_croc(df)

# drop NaNs
df.dropna(inplace=True)

# %%
# Predict the percentage price change over the next 'n' candles
nn = 1
# df['target'] = (df['close'].shift(-nn) - df['close']) / df['close'] * 100

df['target'] = (df['ema_5'].shift(-10) - df['ema_5']) / df['ema_5'] * 100
df.dropna(inplace=True)

# %% [markdown]
# #### Feature Correlation

# %%
corr_matrix = df.corr()
plt.figure(figsize=(16, 8))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt=".2f")
plt.show()

# %%
plt.clf()
plt.figure(figsize=(14, 7))
plt.plot(df.index, df['close'], label='Close', color='blue', alpha=0.8)
plt.plot(df.index, df['ema_10'], label='EMA-10', color='red', alpha=0.5)
plt.plot(df.index, df['ema_5'], label='EMA-5', color='green', alpha=0.5)
plt.legend()
plt.show()

# %%
# df is sorted by time and indexed by a datetime index
n = len(df)
train_end = int(n * 0.8) # 80% data used for training
train_df = df.iloc[:train_end]
test_df = df.iloc[train_end:]

# Separate features and target
X_train = train_df.drop(['target'], axis=1)
y_train = train_df['target']

X_test = test_df.drop(['target'], axis=1)
y_test = test_df['target']

# %%
plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(train_df['close'], label="Actual", alpha=0.8)

# %% [markdown]
# #### Grid Search for Hyperparameter Tuning

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# Define Random Forest
pipeline_rf = Pipeline([
    ('regressor', RandomForestRegressor())
])

# Parameter grid for Random Forest
param_grid_rf = {
    'regressor__n_estimators': [50, 100, 200],
    'regressor__max_depth': [3, 5, 10, 20],
    'regressor__max_features': ['sqrt', 'log2', None],
    'regressor__bootstrap': [True, False]
}

# Define XGBoost
pipeline_xgb = Pipeline([
    ('regressor', XGBRegressor(eval_metric='rmse', use_label_encoder=False))
])

# Parameter grid for XGBoost
param_grid_xgb = {
    'regressor__n_estimators': [50, 100, 200],
    'regressor__max_depth': [3, 5, 10],
    'regressor__learning_rate': [0.01, 0.1, 0.2],
    'regressor__subsample': [0.8, 1.0],
    'regressor__colsample_bytree': [0.8, 1.0]
}

# Time series split
time_series_split = TimeSeriesSplit(n_splits=5)

# Perform grid search for Random Forest
grid_search_rf = GridSearchCV(
    pipeline_rf,
    param_grid_rf,
    scoring='neg_mean_squared_error',
    cv=time_series_split,
    return_train_score=True,
    verbose=3
)
grid_search_rf.fit(X_train, y_train)

# Perform grid search for XGBoost
grid_search_xgb = GridSearchCV(
    pipeline_xgb,
    param_grid_xgb,
    scoring='neg_mean_squared_error',
    cv=time_series_split,
    return_train_score=True,
    verbose=3
)
grid_search_xgb.fit(X_train, y_train)

# Output results
print("Random Forest Best Params:", grid_search_rf.best_params_)
print("Random Forest Best Score:", grid_search_rf.best_score_)
print("XGBoost Best Params:", grid_search_xgb.best_params_)
print("XGBoost Best Score:", grid_search_xgb.best_score_)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.023, test=-0.017) total time=   0.9s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.020, test=-0.030) total time=   1.9s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.023, test=-0.061) total time=   2.9s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.033, test=-0.026) total time=   3.9s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.031, test=-0.045) total time=   4.9s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.023, test=-0.017) total time=   1.9s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.020, test=-0.030) total time=   3.7s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.023, test=-0.061) total time=   5.7s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.033, test=-0.026) total time=   7.7s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.031, test=-0.045) total time=   9.9s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.023, test=-0.017) total time=   3.7s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.020, test=-0.030) total time=   7.4s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.023, test=-0.061) total time=  11.5s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.033, test=-0.026) total time=  15.4s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.031, test=-0.045) total time=  19.6s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.023, test=-0.017) total time=   0.7s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.020, test=-0.032) total time=   1.3s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.023, test=-0.063) total time=   2.1s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.033, test=-0.026) total time=   2.8s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.031, test=-0.046) total time=   3.5s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.023, test=-0.017) total time=   1.4s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.020, test=-0.031) total time=   2.7s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.023, test=-0.061) total time=   4.1s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.033, test=-0.026) total time=   5.5s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.031, test=-0.046) total time=   7.1s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.023, test=-0.017) total time=   2.7s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.020, test=-0.032) total time=   5.4s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.023, test=-0.061) total time=   8.2s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.033, test=-0.026) total time=  11.1s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.031, test=-0.046) total time=  14.2s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=50;, score=(train=-0.022, test=-0.017) total time=   6.4s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=50;, score=(train=-0.020, test=-0.030) total time=  13.3s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=50;, score=(train=-0.023, test=-0.061) total time=  20.4s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=50;, score=(train=-0.032, test=-0.026) total time=  27.7s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=50;, score=(train=-0.031, test=-0.046) total time=  35.4s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=100;, score=(train=-0.022, test=-0.017) total time=  12.9s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=100;, score=(train=-0.020, test=-0.030) total time=  26.5s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=100;, score=(train=-0.023, test=-0.061) total time=  40.6s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=100;, score=(train=-0.032, test=-0.026) total time=  55.3s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=100;, score=(train=-0.031, test=-0.046) total time= 1.2min
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=200;, score=(train=-0.022, test=-0.017) total time=  25.6s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=200;, score=(train=-0.020, test=-0.030) total time=  52.4s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=200;, score=(train=-0.023, test=-0.061) total time= 1.4min
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=200;, score=(train=-0.032, test=-0.026) total time= 1.9min
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=None, regressor__n_estimators=200;, score=(train=-0.031, test=-0.046) total time= 2.4min
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.021, test=-0.017) total time=   1.5s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.019, test=-0.035) total time=   3.0s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.022, test=-0.065) total time=   4.7s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.031, test=-0.026) total time=   6.3s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=50;, score=(train=-0.030, test=-0.045) total time=   8.0s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.021, test=-0.017) total time=   3.0s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.019, test=-0.036) total time=   6.1s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.022, test=-0.064) total time=   9.3s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.031, test=-0.026) total time=  12.7s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=100;, score=(train=-0.030, test=-0.045) total time=  16.3s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.021, test=-0.017) total time=   6.1s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.019, test=-0.036) total time=  12.2s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.022, test=-0.063) total time=  18.7s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.031, test=-0.026) total time=  25.3s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=sqrt, regressor__n_estimators=200;, score=(train=-0.030, test=-0.045) total time=  32.3s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.020, test=-0.017) total time=   1.1s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.019, test=-0.047) total time=   2.2s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.022, test=-0.069) total time=   3.4s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.031, test=-0.026) total time=   4.6s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=50;, score=(train=-0.030, test=-0.045) total time=   5.9s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.021, test=-0.017) total time=   2.2s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.019, test=-0.040) total time=   4.4s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.022, test=-0.067) total time=   6.8s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.031, test=-0.026) total time=   9.1s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=100;, score=(train=-0.030, test=-0.045) total time=  11.6s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.021, test=-0.017) total time=   4.4s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.019, test=-0.040) total time=   8.8s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.022, test=-0.066) total time=  13.5s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.031, test=-0.026) total time=  18.3s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=log2, regressor__n_estimators=200;, score=(train=-0.030, test=-0.045) total time=  23.3s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=None, regressor__n_estimators=50;, score=(train=-0.020, test=-0.017) total time=  10.6s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 45
#      36 # Perform grid search for Random Forest
#      37 grid_search_rf = GridSearchCV(
#      38     pipeline_rf,
#      39     param_grid_rf,
#    (...)
#      43     verbose=3
#      44 )
# ---> 45 grid_search_rf.fit(X_train, y_train)
#      47 # Perform grid search for XGBoost
#      48 grid_search_xgb = GridSearchCV(
#      49     pipeline_xgb,
#      50     param_grid_xgb,
#    (...)
#      54     verbose=3
#      55 )
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1023, in BaseSearchCV.fit(self, X, y, **params)
#    1017     results = self._format_results(
#    1018         all_candidate_params, n_splits, all_out, all_more_results
#    1019     )
#    1021     return results
# -> 1023 self._run_search(evaluate_candidates)
#    1025 # multimetric is determined here because in the case of a callable
#    1026 # self.scoring the return type is only known after calling
#    1027 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1570, in GridSearchCV._run_search(self, evaluate_candidates)
#    1568 def _run_search(self, evaluate_candidates):
#    1569     """Search all candidates in param_grid"""
# -> 1570     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/model_selection/_search.py:969, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     961 if self.verbose > 0:
#     962     print(
#     963         "Fitting {0} folds for each of {1} candidates,"
#     964         " totalling {2} fits".format(
#     965             n_splits, n_candidates, n_candidates * n_splits
#     966         )
#     967     )
# --> 969 out = parallel(
#     970     delayed(_fit_and_score)(
#     971         clone(base_estimator),
#     972         X,
#     973         y,
#     974         train=train,
#     975         test=test,
#     976         parameters=parameters,
#     977         split_progress=(split_idx, n_splits),
#     978         candidate_progress=(cand_idx, n_candidates),
#     979         **fit_and_score_kwargs,
#     980     )
#     981     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     982         enumerate(candidate_params),
#     983         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     984     )
#     985 )
#     987 if len(out) < 1:
#     988     raise ValueError(
#     989         "No fits were performed. "
#     990         "Was the CV iterator empty? "
#     991         "Were there no candidates?"
#     992     )
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:866, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864         estimator.fit(X_train, **fit_params)
#     865     else:
# --> 866         estimator.fit(X_train, y_train, **fit_params)
#     868 except Exception:
#     869     # Note fit time as time until error
#     870     fit_time = time.time() - start_time
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/pipeline.py:660, in Pipeline.fit(self, X, y, **params)
#     654     if self._final_estimator != "passthrough":
#     655         last_step_params = self._get_metadata_for_step(
#     656             step_idx=len(self) - 1,
#     657             step_params=routed_params[self.steps[-1][0]],
#     658             all_params=params,
#     659         )
# --> 660         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     662 return self
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:487, in BaseForest.fit(self, X, y, sample_weight)
#     476 trees = [
#     477     self._make_estimator(append=False, random_state=random_state)
#     478     for i in range(n_more_estimators)
#     479 ]
#     481 # Parallel loop: we prefer the threading backend as the Cython code
#     482 # for fitting the trees is internally releasing the Python GIL
#     483 # making threading more efficient than multiprocessing in
#     484 # that case. However, for joblib 0.12+ we respect any
#     485 # parallel_backend contexts set at a higher level,
#     486 # since correctness does not rely on using threads.
# --> 487 trees = Parallel(
#     488     n_jobs=self.n_jobs,
#     489     verbose=self.verbose,
#     490     prefer="threads",
#     491 )(
#     492     delayed(_parallel_build_trees)(
#     493         t,
#     494         self.bootstrap,
#     495         X,
#     496         y,
#     497         sample_weight,
#     498         i,
#     499         len(trees),
#     500         verbose=self.verbose,
#     501         class_weight=self.class_weight,
#     502         n_samples_bootstrap=n_samples_bootstrap,
#     503         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     504     )
#     505     for i, t in enumerate(trees)
#     506 )
#     508 # Collect newly grown trees
#     509 self.estimators_.extend(trees)
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree._fit(
#     190         X,
#     191         y,
#     192         sample_weight=curr_sample_weight,
#     193         check_input=False,
#     194         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     195     )
#     196 else:
#     197     tree._fit(
#     198         X,
#     199         y,
#    (...)
#     202         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     203     )
#
# File ~/miniconda3/envs/ml-2/lib/python3.11/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# #### Analyse grid search results

# %%
# Access best parameters or results
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
best_score = grid_search.best_score_

# Best model
best_model = grid_search.best_estimator_
# Out:
# Best Parameters: {'regressor__bootstrap': False, 'regressor__max_depth': 3, 'regressor__max_features': 15, 'regressor__n_estimators': 10}
# Best Score: -0.005301410783194906

# %% [markdown]
# #### Save GridSearch Results

# %%
# Save the GridSearchCV object
# joblib.dump(grid_search, 'grid_search_results_1min_neg_nn10.pkl')
# Out:
# ['grid_search_results_1min_neg_nn10.pkl']

# %% [markdown]
# #### Load saves GridSearch results

# %%
# Load GridSearch results
grid_search = joblib.load('grid_search_results_1min_neg_nn10.pkl')
# grid_search = joblib.load('grid_search_results_1sec_nn12.pkl')
# grid_search = joblib.load('grid_search_results.pkl')

# %%
rmse = (-best_score) ** 0.5
print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.10782234849948215

# %%
std_dev = np.std(y_train)
print(f"Target Std Dev: {std_dev}")
# Out:
# Target Std Dev: 0.21952375126212195

# %%
mean_y = np.abs(y_train.mean())
relative_error = rmse / mean_y
print(f"Relative RMSE: {relative_error:.2%}")
# Out:
# Relative RMSE: 4798.06%

# %% [markdown]
# #### Best Model Training

# %%
from sklearn.ensemble import RandomForestRegressor

# Extract best parameters from GridSearchCV
best_params = grid_search.best_params_

# Remove 'regressor__' prefix to pass parameters directly to the model
model_params = {key.replace('regressor__', ''): value for key, value in best_params.items()}

# Train the model using the best parameters
best_model = RandomForestRegressor(**model_params)

# NOTE: Feature scaling is not requiredfor Random Forest regressor
best_model.fit(X_train, y_train)

# Get feature importances
feature_importances = best_model.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
})

# Sort features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the top 10 features
print(feature_importance_df.head(10))
# Out:
#            Feature  Importance
# 41    price_change    0.239488
# 22           roc_5    0.212544
# 16  macd_fast_hist    0.136007
# 39      log_return    0.079226
# 14       macd_fast    0.069885
# 12       macd_hist    0.054026
# 34      williams_r    0.050612
# 24          roc_20    0.047388
# 44         croc_10    0.029685
# 29     candle_body    0.026394

# %%
# Save the model
joblib.dump(best_model, 'best_model_10candles_1min.joblib')
# Out:
# ['best_model_10candles_1min.joblib']

# %%
# load the best model
best_model = joblib.load('best_model_10candles_1min.joblib')

# %% [markdown]
# #### Best Model Prediction

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict on test data
y_pred = best_model.predict(X_test)

# Calculate metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R² Score:", r2)
# Out:
# Mean Squared Error (MSE): 0.005233071057849914
# Mean Absolute Error (MAE): 0.04958422219780115
# R² Score: 0.000663164314149034

# %% [markdown]
# #### Generate Predictions

# %%
# Use the model's predictions
predictions = pd.DataFrame(y_pred)  # Predicted percentage changes
y_pred_train  = pd.DataFrame(best_model.predict(X_train))  # Predicted percentage changes

# %% [markdown]
# ### Trading Signal Generation & Back Testing

# %%
INITIAL_BALANCE = 100  # Starting with $10,000

# %% [markdown]
# #### Trade Simulator

# %%
def simulate_trades(signals, prices, initial_balance=1000):
    """
    Simulates trades based on signals and actual price changes.

    Args:
        actual_changes (list or pd.Series): Actual percentage changes (not predicted).
        signals (list): List of trading signals ("Buy", "Sell", "Hold").
        prices (list or pd.Series): Actual price values for the asset.
        initial_balance (float): Starting balance of the trading account.

    Returns:
        float: Final balance or cumulative profit.
    """
    balance = INITIAL_BALANCE
    position = 0  # Tracks the number of stocks held
    entry_price = None  # Store the price when a "Buy" was executed
    
    for i, signal in enumerate(signals):
        if signal == "Buy" and balance > 0:
            # Execute a buy
            entry_price = prices.iloc[i]  # Use .iloc for positional indexing
            position = balance / entry_price  # Buy with all available balance
            balance = 0  # All balance used to buy
        elif signal == "Sell" and position > 0:
            # Execute a sell
            exit_price = prices.iloc[i]  # Use .iloc for positional indexing
            balance = position * exit_price  # Convert position to cash
            position = 0  # Clear position
            entry_price = None  # Reset entry price after selling

    # If there's a remaining position at the end, calculate its value
    if position > 0 and entry_price is not None:
        balance += position * prices.iloc[-1]  # Use .iloc for positional indexing

    return balance - INITIAL_BALANCE  # Return cumulative profit

# %% [markdown]
# #### Generate a Search Space

# %%
import numpy as np
buy_thresholds = np.arange(-2.0, -0.031, 0.01)
sell_thresholds = np.arange(0.01, 2.0, 0.01)

# Add signals to a DataFrame for analysis
results_df = X_test.copy()
results_df['Predicted Change'] = predictions.shift(-nn).values
# results_df['Predicted Change'] = predictions.values
# Compute predicted prices based on the previous close and Predicted Change
results_df['Predicted Price'] = results_df['close_lag_1'] * (1 + results_df['Predicted Change'] / 100)
results_df.dropna(inplace=True)

# %%
plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(results_df['Predicted Price'], label="Predicted", alpha=0.8)
plt.plot(test_df['close'], label="Actual", alpha=0.8)
plt.legend()
plt.title("Actual vs. Predicted Stock Price Changes (Next Hour)")
plt.xlabel("Time Steps")
plt.ylabel("Percentage Change")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Evaluate Thresholds

# %%
best_buy_threshold = None
best_sell_threshold = None
best_performance = -np.inf

ii = 0
jj = 0
performance = np.zeros((len(buy_thresholds), len(sell_thresholds)))

for buy_th in buy_thresholds:
    for sell_th in sell_thresholds:
        # Generate signals
        trading_signals = [
            "Buy" if pred < buy_th else "Sell" if pred > sell_th else "Hold"
            for pred in results_df['Predicted Change'].values
        ]
        
        # Simulate trades and calculate performance
        performance[ii, jj] = simulate_trades(
            signals=trading_signals,
            prices=results_df['Predicted Price'],  # Use the computed predicted prices
            initial_balance=INITIAL_BALANCE
        )
        # Update best thresholds if current performance is better
        if performance[ii, jj] > best_performance:
            best_performance = performance[ii, jj]
            best_buy_threshold = buy_th
            best_sell_threshold = sell_th
        jj += 1
    ii += 1
    jj = 0
print(f"Best Buy Threshold: {best_buy_threshold}, Best Sell Threshold: {best_sell_threshold}")
print(f"Best Performance: {best_performance}")
# Out:
# Best Buy Threshold: -2.0, Best Sell Threshold: 0.01
# Best Performance: 0.0

# %% [markdown]
# #### Beck Testing

# %%
# Define buy & sell thrsholds
buy_threshold = 0.01
sell_threshold = -2
# Generate signals with reversed logic
trading_signals = [
    "Sell" if pred < buy_threshold else "Buy" if pred > sell_threshold else "Hold"
    for pred in results_df['Predicted Change']
]


# buy_threshold = 0.09
# sell_threshold = -0.13999999999999835
# Generate signals with reversed logic
# trading_signals = [
#     "Buy" if pred > buy_threshold else "Sell" if pred < sell_threshold else "Hold"
#     for pred in results_df['Predicted Change']
# ]

balance = INITIAL_BALANCE
position = 0  # No stock initially
trading_log = []  # To store completed trades



results_df['Signal'] = trading_signals

# Add 'open' and 'close' prices from the original DataFrame to results DataFrame
results_df['open'] = df.loc[results_df.index, 'open']
results_df['close'] = df.loc[results_df.index, 'close']

results_df.dropna(inplace=True)

# Variables to track ongoing trades
buy_price = None
buy_date = None
buy_volume = None

# Iterate over results_df for backtesting
for index, row in results_df.iterrows():
    signal = row['Signal']
    price = row['Predicted Price']  # Use 'open' price for Buy
    # volume = balance / price if signal == "Buy" and balance > 0 else position  # Calculate volume

    if signal == "Buy" and balance > 0:
        # Record Buy details
        buy_price = price
        buy_date = index
        buy_volume = balance / price
        position = buy_volume  # Update position
        balance = 0  # All money is invested

    elif signal == "Sell" and position > 0:
        # Calculate profit/loss for the completed trade
        sell_price = price  # Use 'close' price for Sell
        profit_loss = (sell_price - buy_price) * buy_volume
        balance = sell_price * buy_volume  # Update balance after selling
        position = 0  # No stock left

        # Record the completed trade in the log
        trading_log.append({
            "Buy Date": buy_date,
            "Buy Price": buy_price,
            "Buy Volume": buy_volume,
            "Sell Date": index,
            "Sell Price": sell_price,
            "Profit/Loss": profit_loss
        })

        # Reset Buy details
        buy_price = None
        buy_date = None
        buy_volume = None

# Final portfolio value
if position > 0:
    final_price = results_df.iloc[-1]['Predicted Price']
    final_profit_loss = (final_price - buy_price) * buy_volume
    balance = final_price * buy_volume  # Update balance with remaining shares
    trading_log.append({
        "Buy Date": buy_date,
        "Buy Price": buy_price,
        "Buy Volume": buy_volume,
        "Sell Date": results_df.index[-1],
        "Sell Price": final_price,
        "Profit/Loss": final_profit_loss
    })

# Convert trading log to a DataFrame for better analysis
trading_log_df = pd.DataFrame(trading_log)

# Print the final results
print(f"Final Balance: ${balance:.2f}")
print(f"Net Profit: ${balance - INITIAL_BALANCE:.2f}")
# Out:
# Final Balance: $102.20
# Net Profit: $2.20

# %%
# Save the model
joblib.dump(best_model, 'best_model_10candles_reduced_1min.joblib')
# Out:
# ['best_model_10candles_reduced_1min.joblib']

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Compute Baseline

# %%
# Get starting and ending prices
initial_price = results_df.iloc[0]['close']  # Opening price at the first date
final_price = results_df.iloc[-1]['close']  # Closing price at the last date

# Calculate number of shares purchased with initial balance
shares = INITIAL_BALANCE / initial_price

# Calculate final balance
final_balance_baseline = shares * final_price

# Calculate profit/loss for the baseline strategy
profit_loss_baseline = final_balance_baseline - INITIAL_BALANCE

# Print results
print(f"Baseline Final Balance: ${final_balance_baseline:.2f}")
print(f"Baseline Strategy Profit/Loss: ${profit_loss_baseline:.2f}")
# Out:
# Baseline Final Balance: $96.54
# Baseline Strategy Profit/Loss: $-3.46

# %% [markdown]
# #### Baseline Comparison

# %%
# Assuming `profit_loss_estimator` is calculated from your trading log
profit_loss_estimator = trading_log_df['Profit/Loss'].sum()

# Calculate difference and percentage improvement
difference = profit_loss_estimator - profit_loss_baseline
improvement_percentage = (difference / abs(profit_loss_baseline)) * 100 if profit_loss_baseline != 0 else None

# Print comparison
print(f"Estimator Profit/Loss: ${profit_loss_estimator:.2f}")
print(f"Difference vs. Baseline: ${difference:.2f}")
if improvement_percentage is not None:
    print(f"Performance Improvement: {improvement_percentage:.2f}%")
else:
    print("Baseline profit/loss is zero, percentage improvement cannot be calculated.")
# Out:
# Estimator Profit/Loss: $67421.74
# Difference vs. Baseline: $67425.20
# Performance Improvement: 1947511.90%

# %%
# Calculate momentum (percentage change in price)
momentum_threshold = 0.01  # 1% change as momentum threshold
momentum_signals = results_df['close'].pct_change()  # Calculate percentage change
momentum_trades = momentum_signals[momentum_signals.abs() > momentum_threshold]

# Initialize profit/loss calculation for momentum strategy
momentum_profit_loss = 0
balance = INITIAL_BALANCE
position = 0

# Iterate through momentum trades
for idx, change in momentum_trades.items():  # Use .items() for Series iteration
    price = results_df.loc[idx, 'close']
    if change > 0 and balance > 0:  # Buy signal
        position = balance / price
        balance = 0
    elif change < 0 and position > 0:  # Sell signal
        balance = position * price
        position = 0

# Final balance if still holding shares
if position > 0:
    balance += position * results_df.iloc[-1]['close']

momentum_profit_loss = balance - INITIAL_BALANCE

print(f"Momentum Strategy Profit/Loss: ${momentum_profit_loss:.2f}")
# Out:
# Momentum Strategy Profit/Loss: $0.54

# %%
rolling_window = 20
results_df['SMA'] = results_df['close'].rolling(rolling_window).mean()
results_df['Deviation'] = results_df['close'] - results_df['SMA']

# Drop NaN rows to avoid issues with rolling mean
mean_reversion_trades = results_df.dropna()

# Generate signals explicitly with .loc
mean_reversion_trades.loc[:, 'Signal'] = mean_reversion_trades['Deviation'].apply(
    lambda x: 'Buy' if x < 0 else 'Sell'
)

# Simulate mean-reversion trading
balance = INITIAL_BALANCE
position = 0
mean_reversion_profit_loss = 0

for idx, row in mean_reversion_trades.iterrows():
    price = row['close']
    signal = row['Signal']
    if signal == 'Buy' and balance > 0:  # Buy
        position = balance / price
        balance = 0
    elif signal == 'Sell' and position > 0:  # Sell
        balance = position * price
        position = 0

# Final balance if still holding shares
if position > 0:
    balance += position * results_df.iloc[-1]['close']

mean_reversion_profit_loss = balance - INITIAL_BALANCE

print(f"Mean-Reversion Strategy Profit/Loss: ${mean_reversion_profit_loss:.2f}")
# Out:
# Mean-Reversion Strategy Profit/Loss: $-11.26

# %%
print(f"ML Estimator Profit/Loss: ${profit_loss_estimator:.2f}")
print(f"Baseline Profit/Loss: ${profit_loss_baseline:.2f}")
print(f"Momentum Strategy Profit/Loss: ${momentum_profit_loss:.2f}")
print(f"Mean-Reversion Strategy Profit/Loss: ${mean_reversion_profit_loss:.2f}")
# Out:
# ML Estimator Profit/Loss: $67421.74
# Baseline Profit/Loss: $-3.46
# Momentum Strategy Profit/Loss: $0.54
# Mean-Reversion Strategy Profit/Loss: $-11.26

# %% [markdown]
# ### Visualizations

# %% [markdown]
# ##### Plot Predicted Change

# %%
# Plot the predicted prices
plt.clf()
plt.figure(figsize=(14, 7))
plt.plot(results_df.index, results_df['Predicted Change'], label='Predicted Change', color='blue', alpha=0.7)
plt.plot(results_df.index, y_test, label='Actual Change', color='red', alpha=0.7)


# Use trading_log_df for Buy and Sell points
buy_signals = trading_log_df.dropna(subset=['Buy Date'])
sell_signals = trading_log_df.dropna(subset=['Sell Date'])

# Map Buy/Sell signals to values from results_df['close']
buy_close_prices = [results_df.loc[row['Buy Date'], 'Predicted Change'] for _, row in buy_signals.iterrows()]
sell_close_prices = [results_df.loc[row['Sell Date'], 'Predicted Change'] for _, row in sell_signals.iterrows()]

# Plot Buy signals as green squares at actual 'close' prices
plt.scatter(
    buy_signals['Buy Date'],
    buy_close_prices,
    label='Buy Signal',
    color='green',
    marker='s',
    alpha=0.6
)

# Plot Sell signals as red circles at actual 'close' prices
plt.scatter(
    sell_signals['Sell Date'],
    sell_close_prices,
    label='Sell Signal',
    color='red',
    marker='o',
    alpha=0.6
)

# Add labels, title, legend, and grid
plt.title("Trading Signals Over Predicted Prices (Using Actual Close Prices)")
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt

# Add predicted prices to results_df
results_df['Predicted Price'] = results_df['close'] * (1 + results_df['Predicted Change'] / 100)

# Plot the predicted prices
plt.clf()
plt.figure(figsize=(14, 7))
plt.plot(results_df.index, results_df['Predicted Price'], label='Predicted Price', color='blue', alpha=0.7)

# Use trading_log_df for Buy and Sell points
buy_signals = trading_log_df.dropna(subset=['Buy Date'])
sell_signals = trading_log_df.dropna(subset=['Sell Date'])

# Map Buy/Sell signals to values from results_df['close']
buy_close_prices = [results_df.loc[row['Buy Date'], 'Predicted Price'] for _, row in buy_signals.iterrows()]
sell_close_prices = [results_df.loc[row['Sell Date'], 'Predicted Price'] for _, row in sell_signals.iterrows()]

# Plot Buy signals as green squares at actual 'close' prices
plt.scatter(
    buy_signals['Buy Date'],
    buy_close_prices,
    label='Buy Signal',
    color='green',
    marker='s',
    alpha=0.6
)

# Plot Sell signals as red circles at actual 'close' prices
plt.scatter(
    sell_signals['Sell Date'],
    sell_close_prices,
    label='Sell Signal',
    color='red',
    marker='o',
    alpha=0.6
)

# Add labels, title, legend, and grid
plt.title("Trading Signals Over Predicted Prices (Using Actual Close Prices)")
plt.xlabel("Time")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
corr_matrix = df_reduced.corr()
plt.figure(figsize=(16, 8))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt=".2f")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Parameter Optimization

# %%
from xgboost import XGBRegressor
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Scaling step
    ('regressor', RandomForestRegressor())  # Model
])

# Define hyperparameter grid for the regressor
param_grid = {
    'regressor__n_estimators': [10, 50, 100],
    'regressor__max_depth': [3, 5, 10],
    'regressor__max_features': [5, 10, 15],
    'regressor__bootstrap': [True, False]
}

# Use TimeSeriesSplit for cross-validation
time_series_split = TimeSeriesSplit(n_splits=5)

# Perform grid search with pipeline
grid_search = GridSearchCV(
    pipeline,
    param_grid,
    scoring='neg_mean_squared_error',
    cv=time_series_split,
    return_train_score=True,
    verbose=3
)

# Fit the pipeline
grid_search.fit(X_train_reduced, y_train_reduced)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.005, test=-0.027) total time=   0.3s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.008, test=-0.004) total time=   0.7s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.008, test=-0.002) total time=   1.0s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.008, test=-0.003) total time=   1.3s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.006, test=-0.005) total time=   1.8s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.004, test=-0.026) total time=   1.6s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.008, test=-0.004) total time=   1.8s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.008, test=-0.002) total time=   5.0s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.006, test=-0.002) total time=   6.7s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.006, test=-0.005) total time=   8.4s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.004, test=-0.024) total time=   3.1s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.008, test=-0.004) total time=   6.4s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.008, test=-0.002) total time=   8.4s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.007, test=-0.002) total time=  13.0s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.006, test=-0.004) total time=  15.3s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.002, test=-0.018) total time=   0.6s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.005, test=-0.003) total time=   1.3s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.005, test=-0.001) total time=   1.9s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.004, test=-0.002) total time=   2.6s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.004, test=-0.003) total time=   3.3s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.002, test=-0.017) total time=   3.0s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.005, test=-0.003) total time=   6.2s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.004, test=-0.001) total time=   8.1s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.004, test=-0.001) total time=  12.7s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.004, test=-0.003) total time=  16.1s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.002, test=-0.017) total time=   4.6s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.005, test=-0.002) total time=  12.3s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.004, test=-0.001) total time=  17.6s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.004, test=-0.001) total time=  25.5s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.004, test=-0.003) total time=  31.5s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.002, test=-0.017) total time=   0.7s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.006, test=-0.003) total time=   0.1s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.005, test=-0.002) total time=   2.3s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.005, test=-0.002) total time=   3.1s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.004, test=-0.004) total time=   3.9s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.002, test=-0.017) total time=   3.5s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.006, test=-0.003) total time=   7.5s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.005, test=-0.002) total time=  11.4s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.005, test=-0.002) total time=  13.8s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.004, test=-0.004) total time=  18.1s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.002, test=-0.016) total time=   7.1s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.005, test=-0.003) total time=  14.7s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.005, test=-0.002) total time=  21.5s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.005, test=-0.002) total time=  29.2s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.004, test=-0.004) total time=  38.2s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.001, test=-0.010) total time=   0.5s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.002, test=-0.001) total time=   1.2s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.003, test=-0.001) total time=   1.6s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.002, test=-0.001) total time=   2.1s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.002, test=-0.002) total time=   2.6s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.001, test=-0.012) total time=   2.4s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.002, test=-0.001) total time=   3.7s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.002, test=-0.001) total time=   7.7s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.001, test=-0.001) total time=  10.7s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.001, test=-0.002) total time=  13.6s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.001, test=-0.013) total time=   3.6s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.002, test=-0.001) total time=  10.1s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.002, test=-0.001) total time=  15.3s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.002, test=-0.001) total time=  20.0s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.001, test=-0.001) total time=  25.7s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.007) total time=   1.0s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   2.1s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   3.2s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   4.3s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   5.3s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.007) total time=   3.4s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=   9.9s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  15.8s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  19.3s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  23.9s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.007) total time=   9.4s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  18.4s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  28.5s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  39.5s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  50.3s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.006) total time=  -0.2s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   2.4s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   3.7s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   5.0s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   6.2s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.006) total time=   5.7s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  10.7s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  18.3s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  23.3s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  29.7s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.006) total time=  11.4s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  22.3s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  34.8s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  45.7s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.0min
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.008) total time=  -0.5s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   1.9s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   2.9s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   3.9s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.001) total time=   5.0s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.007) total time=   4.6s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=   9.7s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  13.0s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  19.4s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  23.1s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.007) total time=   8.9s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  17.6s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  27.3s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  37.4s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  47.0s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.005) total time=   1.8s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   3.8s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   5.7s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   7.6s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=  10.0s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.005) total time=   7.6s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  18.9s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  26.6s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  36.6s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  44.0s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.005) total time=  17.0s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  35.4s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  52.8s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.2min
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.5min
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.005) total time=   2.1s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   4.5s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   6.8s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   9.1s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=  10.3s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.004) total time=  10.3s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  20.8s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  32.8s
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  43.8s
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  54.1s
# [CV 1/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.004) total time=  20.5s
# [CV 2/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  40.9s
# [CV 3/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.1min
# [CV 4/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.5min
# [CV 5/5] END regressor__bootstrap=True, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.8min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.006, test=-0.028) total time=   0.5s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.010, test=-0.005) total time=   0.9s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.007, test=-0.002) total time=   1.5s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.007, test=-0.002) total time=   1.9s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.006, test=-0.005) total time=   2.3s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.004, test=-0.026) total time=   2.1s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.009, test=-0.005) total time=   4.5s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.008, test=-0.002) total time=   5.4s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.007, test=-0.002) total time=   9.4s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.006, test=-0.004) total time=  11.6s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.004, test=-0.024) total time=   4.3s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.009, test=-0.005) total time=   7.9s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.008, test=-0.002) total time=  19.0s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.007, test=-0.002) total time=  17.9s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.006, test=-0.005) total time=  23.6s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.002, test=-0.018) total time=   0.9s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.006, test=-0.003) total time=   1.8s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.005, test=-0.002) total time=   2.8s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.005, test=-0.002) total time=   3.7s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.004, test=-0.003) total time=   4.6s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.002, test=-0.017) total time=   4.2s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.006, test=-0.003) total time=   9.0s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.005, test=-0.002) total time=  12.2s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.004, test=-0.002) total time=  18.1s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.004, test=-0.003) total time=  22.1s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.002, test=-0.017) total time=   8.5s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.006, test=-0.003) total time=  16.4s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.005, test=-0.002) total time=  25.4s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.004, test=-0.002) total time=  35.2s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.004, test=-0.003) total time=  44.9s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.003, test=-0.017) total time=   1.0s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.007, test=-0.004) total time=   2.2s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.006, test=-0.003) total time=   3.3s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.005, test=-0.003) total time=   4.4s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.005, test=-0.005) total time=   4.3s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.003, test=-0.017) total time=   5.1s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.007, test=-0.004) total time=  10.7s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.006, test=-0.003) total time=  15.4s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.005, test=-0.003) total time=  22.8s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.005, test=-0.005) total time=  29.1s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.003, test=-0.017) total time=   9.4s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.007, test=-0.004) total time=  25.5s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.006, test=-0.003) total time=  44.7s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.005, test=-0.003) total time= 1.0min
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=3, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.005, test=-0.005) total time= 1.2min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.001, test=-0.012) total time=   1.0s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.003, test=-0.002) total time=   1.9s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.003, test=-0.001) total time=   3.1s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.001, test=-0.001) total time=   4.2s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.002, test=-0.002) total time=   5.2s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.001, test=-0.012) total time=   4.6s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.002, test=-0.001) total time=   8.5s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.002, test=-0.001) total time=  15.1s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.001, test=-0.001) total time=  19.0s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.001, test=-0.001) total time=  25.1s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.001, test=-0.012) total time=   9.6s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.002, test=-0.001) total time=  20.1s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.002, test=-0.001) total time=  29.6s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.002, test=-0.001) total time=  39.3s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.001, test=-0.002) total time=  49.4s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.007) total time=   1.9s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.001, test=-0.000) total time=   4.0s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   4.8s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   8.5s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=  10.6s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.007) total time=   8.2s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  19.8s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  30.1s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  40.0s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  48.1s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.007) total time=  12.7s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  34.8s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  56.3s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.4min
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.7min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.006) total time=   2.3s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.001, test=-0.000) total time=   4.9s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.001, test=-0.000) total time=   7.5s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   9.1s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=  13.2s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.006) total time=  11.7s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.001, test=-0.000) total time=  22.9s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.001, test=-0.000) total time=  36.6s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  49.4s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time= 1.0min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.006) total time=  22.4s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.001, test=-0.000) total time=  47.9s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.001, test=-0.000) total time= 1.2min
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.6min
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=5, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 2.1min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.006) total time=   1.8s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   3.9s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   5.9s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   8.0s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   9.1s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.006) total time=   9.4s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  18.3s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  28.2s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  28.7s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  34.8s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.006) total time=  13.4s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  26.7s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  41.5s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  55.7s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=5, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.2min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.004) total time=   2.6s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   4.3s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   8.4s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=  11.6s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=  13.2s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.004) total time=  13.1s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  25.7s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  39.9s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  54.3s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time= 1.2min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.004) total time=  24.6s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time=  52.2s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.3min
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.8min
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=10, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 2.3min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.004) total time=   3.0s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   5.1s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=   9.8s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=  13.7s
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=10;, score=(train=-0.000, test=-0.000) total time=  16.6s
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.004) total time=  15.5s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  31.5s
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time=  48.6s
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time= 1.1min
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=50;, score=(train=-0.000, test=-0.000) total time= 1.4min
# [CV 1/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.004) total time=  29.1s
# [CV 2/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.0min
# [CV 3/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 1.6min
# [CV 4/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 2.2min
# [CV 5/5] END regressor__bootstrap=False, regressor__max_depth=10, regressor__max_features=15, regressor__n_estimators=100;, score=(train=-0.000, test=-0.000) total time= 2.7min
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('regressor', RandomForestRegressor())]),
#              param_grid={'regressor__bootstrap': [True, False],
#                          'regressor__max_depth': [3, 5, 10],
#                          'regressor__max_features': [5, 10, 15],
#                          'regressor__n_estimators': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %% [markdown]
# #### Save GridSearch Results

# %%
# Save the GridSearchCV object
joblib.dump(grid_search, 'grid_search_results_1min_reduced.pkl')

# %% [markdown]
# ### Dry Run Analysis

# %%
# Import the class from the Python file (module)
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
from BinanceClient import BinanceClient
import numpy as np
from typing import Final
import joblib
from BatchFeatures import BatchFeatures
from datetime import datetime, timedelta
import pytz
# %matplotlib widget

# %%
# Initialize Binance client with your API credentials
# dotenv_path = Path('.env-secret')
# load_dotenv(dotenv_path=dotenv_path)
api_secret = os.getenv("BINANCE_SECRET_KEY")
api_key = os.getenv("BINANCE_API_KEY")

# Create Binance client & initialize it
pair = "BTCUSDT"
db_name = "BTCUSDT_1min_dry_run_analysis.db"             # For dry run testing
binance_client = BinanceClient(db_name)
binance_client.set_interval("1m")
batch_feature = BatchFeatures()

# Create connection to fetch data
binance_client.make(api_key, api_secret)

# Fixed start and end times for the 8-hour dry run test
start_date = datetime.strptime("2024-12-30 02:43:00", "%Y-%m-%d %H:%M:%S")
end_date = datetime.strptime("2024-12-30 09:47:00", "%Y-%m-%d %H:%M:%S")

# Ensure timezone is set to UTC
start_date = start_date.replace(tzinfo=pytz.UTC)
end_date = end_date.replace(tzinfo=pytz.UTC)

start_date_str = int(start_date.timestamp() * 1000)  # Convert to milliseconds
end_date_str = int(end_date.timestamp() * 1000)      # Convert to milliseconds

# Fetch data
data = binance_client.fetch_data(pair, start_date_str, end_date_str)
if data is not None and not data.empty:
    binance_client.store_data_to_db(pair, data)
    df = data
    print("Data fetched and stored successfully.")
else:
    print("No data found!!!.")
# Out:
# Fetching data from Binance API...
# Data fetched and stored successfully.

# %%
#Fetch data from db
# df = binance_client.fetch_data_from_db(pair)

batch_feature = BatchFeatures()
batch_feature.calculate_sma(df)
batch_feature.calculate_ema(df)
batch_feature.calculate_rsi(df)
batch_feature.calculate_macd(df)
batch_feature.calculate_bollinger_bands(df)
batch_feature.calculate_atr(df)
batch_feature.calculate_volume_features(df)
batch_feature.calculate_roc(df)
batch_feature.calculate_lagged_features(df)
batch_feature.calculate_candle_features(df)
# Drop NaNs
df.dropna(inplace=True)

# Drop Close form test set
X_test = df.drop(['close'], axis=1)

# Load the best model
best_model = joblib.load('best_model_10candles_reduced_1min.joblib')
# The model predicts 'close price' for next 1 hr i.e. 12 candles @ 5_min_interval
span = 10

# Generate predictions
predictions = pd.DataFrame(best_model.predict(X_test))

# Add signals to a DataFrame for analysis
results_df = X_test.copy()
# results_df['Predicted Change'] = predictions.shift(-nn).values
results_df['Predicted Change'] = predictions.values

# Compute predicted prices based on the previous close and Predicted Change
results_df['Predicted Price'] = results_df['close_lag_1'] * (1 + results_df['Predicted Change'] / 100)

# plot the results
plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(df['close'], label="Actual Close", alpha=0.8)
plt.plot(results_df['Predicted Price'], label="Predicted", alpha=0.8)
plt.legend()
plt.title("Actual vs. Predicted Stock Price Changes (Next Hour)")
plt.xlabel("Time Steps")
plt.ylabel("Percentage Change")
plt.show()

# %%
#Fetch data from db
df = binance_client.fetch_data_from_db(pair)

batch_feature = BatchFeatures()
batch_feature.calculate_sma(df)
batch_feature.calculate_ema(df)
batch_feature.calculate_rsi(df)
batch_feature.calculate_macd(df)
batch_feature.calculate_bollinger_bands(df)
batch_feature.calculate_atr(df)
batch_feature.calculate_volume_features(df)
batch_feature.calculate_roc(df)
batch_feature.calculate_lagged_features(df)
batch_feature.calculate_candle_features(df)
# Drop NaNs
df.dropna(inplace=True)

# Drop Close from test set
X_test = df.drop(['close'], axis=1)

# Load the best model
best_model = joblib.load('best_model_10candles_reduced_1min.joblib')
span = 10  # Number of candles ahead the model predicts

# Generate predictions
predictions = pd.DataFrame(best_model.predict(X_test), index=X_test.index, columns=["Predicted Change"])

# Add predictions to a DataFrame
results_df = df.copy()
results_df['Predicted Change'] = predictions.shift(-span).values  # Shift predictions forward by `span`

# Compute predicted prices based on the previous close and Predicted Change
results_df['Predicted Price'] = results_df['close'] * (1 + results_df['Predicted Change'] / 100)

# Plot the results with proper alignment
plt.clf()
plt.figure(figsize=(12, 6))
plt.plot(df['close'], label="Actual Close", alpha=0.8)
plt.plot(results_df['Predicted Price'], label="Predicted (Aligned)", alpha=0.8)
plt.legend()
plt.title("Actual vs. Predicted Stock Price Changes (Next Hour)")
plt.xlabel("Time Steps")
plt.ylabel("Price")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Misc Code

# %%
import cupy as cp
X_train_gpu = cp.array(X_train)
y_train_gpu = cp.array(y_train)

# %%
def simulate_trades_with_penalty(predicted_changes, signals, initial_balance=1000):
    balance = initial_balance
    position = 0
    trades = 0  # Count the number of trades
    penalty = 0  # Initialize penalty for excessive trading

    for change, signal in zip(predicted_changes, signals):
        if signal == "Buy":
            position += balance / 100
            balance = 0
            trades += 1
        elif signal == "Sell" and position > 0:
            balance += position * (1 + change / 100)
            position = 0
            trades += 1
        # "Hold" means do nothing
    
    balance += position * (1 + predicted_changes.iloc[-1] / 100)
    
    # Apply penalty for excessive trades
    penalty = -0.01 * trades  # Example penalty, adjust as needed
    return balance - initial_balance + penalty

# %%
import sqlite3
db_name="binance_data.db"
conn = sqlite3.connect(db_name)
cursor = conn.cursor()
cursor.execute("PRAGMA journal_mode=DELETE;")
conn.commit()
conn.close()
